# %%
# The idea behind this is that players in the madden video games have 0-99 overall ratings
# and a bunch of other 0-99 ratings for specific attributes like speed, awareness, throw power, etc.
# my idea behind this project is to use regression to get the overall rating from these more specific ratings

# %%
import pandas
import statsmodels.api as sm
import numpy as np
from patsy import dmatrices
from sklearn.preprocessing import StandardScaler

# %%
def validate(validation,params):
    top_weights = params[1:].to_numpy()
    top_features = params[1:].index.to_numpy()
    dict = {}
    for a, b in zip(top_features, top_weights):
        dict[a] = b
    #print(dict)
    array=[]
    for i in dict:
        array.append(i)
    #print(validation)
    features=validation[array].to_numpy()
    labels=validation[['overall_rating']].to_numpy()
    weights=params.to_numpy()
    #print(features)
    #print(weights[1:])
    errors=np.matmul(features,weights[1:])+weights[0]-labels.transpose()
    return np.average(np.absolute(errors))

# %%
def findPositions(data):
    c = data.to_numpy()
    q = c[:, 2]
    return (np.unique(q))

# %%
def doRegressionAndPCA(data,Position):    
    pos=data[data['Position']==Position] # filtering data for given position
    all_ratings = ['awareness_rating','throwPower_rating','kickReturn_rating','leadBlock_rating','strength_rating','bCVision_rating','catchInTraffic_rating','playAction_rating','pursuit_rating','mediumRouteRunning_rating','catching_rating','acceleration_rating','spinMove_rating','finesseMoves_rating','spectacularCatch_rating','runBlock_rating','tackle_rating','injury_rating','zoneCoverage_rating','deepRouteRunning_rating','trucking_rating','throwAccuracyShort_rating','jukeMove_rating','playRecognition_rating','shortRouteRunning_rating','breakSack_rating','speed_rating','runBlockPower_rating','jumping_rating','toughness_rating','throwOnTheRun_rating','manCoverage_rating','stiffArm_rating','powerMoves_rating','release_rating','hitPower_rating','throwAccuracyMid_rating','kickAccuracy_rating','passBlockPower_rating','impactBlocking_rating','stamina_rating','carrying_rating','breakTackle_rating','kickPower_rating','throwUnderPressure_rating','passBlock_rating','changeOfDirection_rating','press_rating','throwAccuracyDeep_rating','blockShedding_rating','runBlockFinesse_rating','agility_rating','passBlockFinesse_rating']
    features=all_ratings
    all_ratings.append('overall_rating')
    #print(features)
    pos_ratings=pos[all_ratings]
    training=pos_ratings.sample(frac=.9,random_state=1) # take 80% as training data
    test_rows=np.setdiff1d(pos_ratings.index,training.index)
    array=np.zeros(data.index.size)
    for n in range(data.index.size):
        array[n]=(n in test_rows)
        array=np.array(array,dtype=bool)

    test=data.loc[array]
    
    test=test[all_ratings]
    #print(validation)
    # makes the rest of the data the validation set
    
    # Separating out the features
    x = training.loc[:, features].values
    test_x=test.loc[:, features].values
    scaler=StandardScaler()
    scaler.fit(x)
    x = scaler.transform(x)
    test_x=scaler.transform(test_x)
    #print(x)
    from sklearn.decomposition import PCA
    pca = PCA(.95)
    pca.fit(x)
    principalComponents = pca.transform(x)
    principalComponents_test=pca.transform(test_x)
    #columns=np.zeros([pca.n_components_,1],dtype='<U22')
    columns=[]
    for i in range(pca.n_components_):
        columns.append('principal_component_'+str(i+1))
    #print(columns) 
    #print(principalComponents)
    principalDf = pandas.DataFrame(data = principalComponents
             , columns = columns)
    testDf = pandas.DataFrame(data = principalComponents_test
             , columns = columns)
    labelsdf = pandas.DataFrame(data = training[['overall_rating']].to_numpy()
             , columns = ['overall_rating'])
    labelsdf_test=pandas.DataFrame(data = test[['overall_rating']].to_numpy()
             , columns = ['overall_rating'])
    
    finalDf = pandas.concat([principalDf, labelsdf], axis = 1)
    finalDf_test=pandas.concat([testDf, labelsdf_test], axis = 1)
    #print(columns+'+')
    reg_string='overall_rating ~ '
    for i in columns:
        reg_string+=i+'+'
    reg_string=reg_string[:-1]
    y, X =dmatrices(reg_string,data=finalDf, return_type='dataframe')
    mod = sm.OLS(y, X)
    res = mod.fit()
    #print(validate(finalDf_test,res.params))
    #pca.explained_variance_ratio_
    print('Average absolute error for ' +Position + ' on test set: '+str(validate(finalDf_test,res.params)))
    return res.params

# %%
data=pandas.read_csv('Madden_23_Player_Ratings.csv') # Read data
allPositions = findPositions(data)

#to print everything do this
for pos in allPositions:
    print(doRegressionAndPCA(data, pos))
    print('')

#or just one, do this
#print(doRegression(data, 'QB'))

# change the argument here to do regression on whichever position
# Out:
# Average absolute error for C on test set: 0.5647576114293367
# Intercept                 66.500000
# principal_component_1     -1.510106
# principal_component_2      2.577566
# principal_component_3      0.496582
# principal_component_4     -0.255283
# principal_component_5      0.124463
# principal_component_6      0.227060
# principal_component_7     -0.253247
# principal_component_8      0.220391
# principal_component_9      0.337655
# principal_component_10     0.236283
# principal_component_11    -0.172107
# principal_component_12    -0.073500
# principal_component_13     0.420155
# principal_component_14    -0.240272
# principal_component_15    -0.371699
# principal_component_16     0.264986
# principal_component_17    -0.103529
# principal_component_18    -0.439615
# principal_component_19    -0.199664
# principal_component_20    -0.422822
# principal_component_21     0.665129
# principal_component_22     0.474405
# principal_component_23    -0.547353
# principal_component_24    -0.030651
# dtype: float64
#
# Average absolute error for CB on test set: 0.7338011588868937
# Intercept                 70.820717
# principal_component_1      2.109745
# principal_component_2     -1.193430
# principal_component_3     -0.129645
# principal_component_4      0.673675
# principal_component_5     -0.351983
# principal_component_6      1.060524
# principal_component_7     -0.560116
# principal_component_8      0.581680
# principal_component_9     -0.115517
# principal_component_10    -0.029119
# principal_component_11    -0.007843
# principal_component_12     0.529358
# principal_component_13     0.511654
# principal_component_14    -0.350562
# principal_component_15    -0.103661
# principal_component_16     0.228789
# principal_component_17     0.249822
# principal_component_18    -0.264700
# principal_component_19    -0.165991
# principal_component_20     0.109737
# principal_component_21    -0.463996
# principal_component_22    -0.200047
# principal_component_23    -0.154498
# principal_component_24    -0.026580
# principal_component_25    -0.341971
# principal_component_26    -0.200619
# principal_component_27    -0.237169
# principal_component_28     0.016907
# principal_component_29    -0.026591
# principal_component_30     0.282193
# dtype: float64
#
# Average absolute error for DT on test set: 0.7980827251719129
# Intercept                 69.933333
# principal_component_1      1.359302
# principal_component_2     -1.810738
# principal_component_3      0.932801
# principal_component_4      0.860337
# principal_component_5     -0.018786
# principal_component_6      0.236138
# principal_component_7      0.368654
# principal_component_8     -0.929287
# principal_component_9      0.186667
# principal_component_10     0.068291
# principal_component_11    -0.071699
# principal_component_12    -0.062129
# principal_component_13     0.619010
# principal_component_14    -0.336891
# principal_component_15     0.261101
# principal_component_16    -0.568635
# principal_component_17    -0.159546
# principal_component_18    -0.016127
# principal_component_19    -0.529118
# principal_component_20     0.373095
# principal_component_21     0.056840
# principal_component_22     0.001948
# principal_component_23     0.573959
# principal_component_24     0.614693
# principal_component_25    -0.925064
# principal_component_26     0.446524
# dtype: float64
#
# Average absolute error for FB on test set: 0.7973824800559962
# Intercept                 67.640000
# principal_component_1     -0.247488
# principal_component_2      2.272626
# principal_component_3      0.165890
# principal_component_4      0.242353
# principal_component_5     -0.084187
# principal_component_6      0.476780
# principal_component_7      0.187888
# principal_component_8     -0.548639
# principal_component_9     -0.062092
# principal_component_10    -0.959399
# principal_component_11     0.185107
# principal_component_12    -0.106337
# principal_component_13    -0.066253
# principal_component_14    -0.611445
# dtype: float64
#
# Average absolute error for FS on test set: 1.2556958060145291
# Intercept                 71.476744
# principal_component_1      2.445379
# principal_component_2     -0.325025
# principal_component_3     -0.372624
# principal_component_4      0.417871
# principal_component_5     -0.363522
# principal_component_6     -0.594708
# principal_component_7      0.588183
# principal_component_8      0.614463
# principal_component_9     -0.128609
# principal_component_10    -0.823289
# principal_component_11    -0.345622
# principal_component_12     0.459627
# principal_component_13    -0.035216
# principal_component_14     0.541130
# principal_component_15     0.197272
# principal_component_16     0.147292
# principal_component_17    -0.325608
# principal_component_18    -0.415984
# principal_component_19     0.127418
# principal_component_20    -0.240404
# principal_component_21    -0.249237
# principal_component_22    -0.021024
# principal_component_23     0.411614
# principal_component_24     0.207074
# principal_component_25     0.260278
# principal_component_26     0.142266
# principal_component_27     0.063110
# dtype: float64
#
# Average absolute error for HB on test set: 1.1216623433606618
# Intercept                 72.530201
# principal_component_1      2.073087
# principal_component_2      0.326628
# principal_component_3     -0.717958
# principal_component_4      1.376130
# principal_component_5     -1.293620
# principal_component_6      0.444843
# principal_component_7      0.426159
# principal_component_8     -0.066388
# principal_component_9     -0.383729
# principal_component_10    -0.290332
# principal_component_11    -0.293406
# principal_component_12    -0.435833
# principal_component_13    -0.060666
# principal_component_14     0.082086
# principal_component_15     0.582600
# principal_component_16    -0.909365
# principal_component_17     0.597819
# principal_component_18    -0.109102
# principal_component_19     0.581908
# principal_component_20     0.277850
# principal_component_21    -0.451249
# principal_component_22     0.232854
# principal_component_23    -0.570869
# principal_component_24     1.048411
# principal_component_25     0.104628
# principal_component_26     0.136752
# principal_component_27     0.379820
# principal_component_28    -0.105736
# principal_component_29    -0.208692
# dtype: float64
#
# Average absolute error for K on test set: 1.4686813113967538
# Intercept                 74.222222
# principal_component_1     -1.014562
# principal_component_2     -0.617051
# principal_component_3      0.689373
# principal_component_4      0.455398
# principal_component_5      1.276337
# principal_component_6      1.612851
# principal_component_7      0.249848
# principal_component_8     -0.359836
# principal_component_9     -1.018358
# principal_component_10    -0.036022
# principal_component_11     0.242002
# principal_component_12     0.414476
# principal_component_13     0.746964
# principal_component_14     0.120566
# principal_component_15    -0.659883
# principal_component_16    -0.194929
# principal_component_17     0.415276
# principal_component_18    -0.202921
# principal_component_19    -0.086028
# principal_component_20    -1.013924
# dtype: float64
#
# Average absolute error for LE on test set: 0.8938706206885214
# Intercept                 70.010989
# principal_component_1      1.107170
# principal_component_2     -1.598992
# principal_component_3      1.433477
# principal_component_4     -0.261582
# principal_component_5      0.384648
# principal_component_6     -0.491724
# principal_component_7      0.304544
# principal_component_8      0.215346
# principal_component_9     -0.463534
# principal_component_10     0.482597
# principal_component_11    -0.209604
# principal_component_12    -0.030901
# principal_component_13     0.093292
# principal_component_14     0.214266
# principal_component_15     0.280425
# principal_component_16     0.034425
# principal_component_17    -0.275021
# principal_component_18     0.077853
# principal_component_19     0.274701
# principal_component_20    -0.297310
# principal_component_21    -0.187425
# principal_component_22     0.920482
# principal_component_23    -0.077090
# principal_component_24    -0.650306
# principal_component_25    -0.066520
# dtype: float64
#
# Average absolute error for LG on test set: 0.6746589289346251
# Intercept                 67.808824
# principal_component_1      0.563986
# principal_component_2      2.580903
# principal_component_3     -0.499389
# principal_component_4      0.044217
# principal_component_5     -0.198359
# principal_component_6     -0.064825
# principal_component_7     -0.004916
# principal_component_8     -0.088239
# principal_component_9     -0.323141
# principal_component_10    -0.094560
# principal_component_11     0.072778
# principal_component_12     0.036861
# principal_component_13    -0.139042
# principal_component_14     0.518669
# principal_component_15     0.127261
# principal_component_16     0.129744
# principal_component_17     0.252661
# principal_component_18     0.303964
# principal_component_19     0.066999
# principal_component_20    -0.251062
# principal_component_21     0.270305
# principal_component_22     0.001651
# principal_component_23     0.146835
# principal_component_24     0.305994
# dtype: float64
#
# Average absolute error for LOLB on test set: 1.0386614345581073
# Intercept                 68.413793
# principal_component_1     -0.934546
# principal_component_2      2.255155
# principal_component_3     -1.206339
# principal_component_4      0.514131
# principal_component_5      0.477140
# principal_component_6      0.881283
# principal_component_7      0.243744
# principal_component_8      0.103892
# principal_component_9     -0.620070
# principal_component_10     0.437843
# principal_component_11    -0.628537
# principal_component_12    -0.170714
# principal_component_13     0.345051
# principal_component_14     0.405985
# principal_component_15    -0.027457
# principal_component_16     0.128455
# principal_component_17    -0.391287
# principal_component_18    -0.243569
# principal_component_19     0.256245
# principal_component_20     0.158635
# principal_component_21     0.110086
# principal_component_22    -0.177589
# principal_component_23     0.097665
# principal_component_24     0.395545
# principal_component_25     0.041438
# dtype: float64
#
# Average absolute error for LT on test set: 1.1726072017937987
# Intercept                 69.000000
# principal_component_1      2.026737
# principal_component_2     -2.482544
# principal_component_3     -0.125850
# principal_component_4      0.320776
# principal_component_5     -0.048590
# principal_component_6      0.836822
# principal_component_7      0.096260
# principal_component_8      0.128734
# principal_component_9     -0.240342
# principal_component_10    -0.670331
# principal_component_11    -0.281789
# principal_component_12     0.421957
# principal_component_13     0.271863
# principal_component_14     0.302381
# principal_component_15     0.679458
# principal_component_16     0.670537
# principal_component_17     0.418457
# principal_component_18     0.083383
# principal_component_19    -0.045424
# principal_component_20    -0.084114
# principal_component_21    -0.158707
# principal_component_22     0.172673
# principal_component_23     0.185913
# principal_component_24    -0.031700
# principal_component_25    -0.317234
# dtype: float64
#
# Average absolute error for MLB on test set: 0.6617807763117156
# Intercept                 69.765625
# principal_component_1     -1.042918
# principal_component_2      2.545786
# principal_component_3     -0.315104
# principal_component_4      0.133340
# principal_component_5      0.446575
# principal_component_6     -0.080842
# principal_component_7     -0.335666
# principal_component_8      0.027889
# principal_component_9      0.145407
# principal_component_10     0.419694
# principal_component_11     0.106045
# principal_component_12    -0.203287
# principal_component_13    -0.098672
# principal_component_14     0.677414
# principal_component_15    -0.502826
# principal_component_16     0.217445
# principal_component_17     0.530633
# principal_component_18     0.010618
# principal_component_19    -0.603681
# principal_component_20     0.336866
# principal_component_21    -0.317954
# principal_component_22     0.539815
# principal_component_23    -0.224989
# principal_component_24    -0.310840
# principal_component_25    -0.537263
# principal_component_26     0.126116
# dtype: float64
#
# Average absolute error for P on test set: 0.762011720432195
# Intercept                 74.375000
# principal_component_1     -0.054526
# principal_component_2     -0.529690
# principal_component_3      0.966572
# principal_component_4     -1.011337
# principal_component_5      0.849696
# principal_component_6     -1.428656
# principal_component_7     -0.572036
# principal_component_8     -0.445891
# principal_component_9      0.776338
# principal_component_10     0.222260
# principal_component_11    -0.716301
# principal_component_12     0.315048
# principal_component_13    -0.047501
# principal_component_14    -0.177280
# principal_component_15     0.023669
# principal_component_16     0.186147
# principal_component_17     0.054196
# dtype: float64
# Average absolute error for QB on test set: 0.6636504038320077
# Intercept                 65.881720
# principal_component_1      1.836454
# principal_component_2     -2.401814
# principal_component_3     -1.328103
# principal_component_4      0.921819
# principal_component_5     -0.965485
# principal_component_6     -0.137243
# principal_component_7     -0.561222
# principal_component_8     -0.687613
# principal_component_9      0.242886
# principal_component_10    -0.278699
# principal_component_11    -0.314556
# principal_component_12    -0.181581
# principal_component_13    -0.303714
# principal_component_14     0.871599
# principal_component_15     0.131098
# principal_component_16     0.726977
# principal_component_17     0.419282
# principal_component_18    -0.524511
# principal_component_19    -0.008312
# principal_component_20     0.219509
# principal_component_21    -0.076216
# principal_component_22     0.367553
# principal_component_23     0.079259
# principal_component_24    -0.664617
# dtype: float64
#
# Average absolute error for RE on test set: 1.2743182324991835
# Intercept                 70.505618
# principal_component_1     -0.405077
# principal_component_2      2.589422
# principal_component_3      0.220924
# principal_component_4      0.828390
# principal_component_5      0.428737
# principal_component_6     -0.428635
# principal_component_7     -0.065425
# principal_component_8      0.571661
# principal_component_9      0.702078
# principal_component_10    -0.142233
# principal_component_11    -0.225612
# principal_component_12     0.321024
# principal_component_13     0.670349
# principal_component_14    -0.353950
# principal_component_15     0.171808
# principal_component_16     0.146092
# principal_component_17    -0.130330
# principal_component_18    -0.511460
# principal_component_19    -0.386033
# principal_component_20    -0.276067
# principal_component_21     0.031852
# principal_component_22    -0.025133
# principal_component_23     0.754795
# dtype: float64
#
# Average absolute error for RG on test set: 0.343807463344338
# Intercept                 67.492754
# principal_component_1     -0.803366
# principal_component_2      2.439917
# principal_component_3      0.250820
# principal_component_4     -0.056876
# principal_component_5      0.261008
# principal_component_6     -0.073801
# principal_component_7      0.009488
# principal_component_8      0.473489
# principal_component_9     -0.058569
# principal_component_10     0.031050
# principal_component_11     0.503463
# principal_component_12    -0.018584
# principal_component_13     0.068344
# principal_component_14     0.188969
# principal_component_15    -0.391728
# principal_component_16     0.038960
# principal_component_17    -0.004008
# principal_component_18     0.367112
# principal_component_19     0.316977
# principal_component_20    -0.239656
# principal_component_21    -0.160772
# principal_component_22    -0.260976
# principal_component_23    -0.021842
# principal_component_24    -0.533968
# dtype: float64
#
# Average absolute error for ROLB on test set: 1.1801816534521774
# Intercept                 70.187500
# principal_component_1      0.163932
# principal_component_2      2.661581
# principal_component_3     -0.105637
# principal_component_4      0.767942
# principal_component_5     -0.327924
# principal_component_6     -0.449582
# principal_component_7     -1.030652
# principal_component_8     -0.370932
# principal_component_9      0.635662
# principal_component_10    -0.241035
# principal_component_11     0.426084
# principal_component_12    -0.252584
# principal_component_13     0.454882
# principal_component_14     0.038350
# principal_component_15    -0.468714
# principal_component_16     0.236557
# principal_component_17     0.588692
# principal_component_18     0.068146
# principal_component_19     0.377981
# principal_component_20     0.121069
# principal_component_21     0.078648
# principal_component_22     0.146848
# principal_component_23     0.090191
# dtype: float64
#
# Average absolute error for RT on test set: 0.6661550127939933
# Intercept                 65.986842
# principal_component_1      1.534388
# principal_component_2      2.581135
# principal_component_3     -0.004874
# principal_component_4     -0.404017
# principal_component_5      0.584030
# principal_component_6     -0.088534
# principal_component_7      0.064500
# principal_component_8     -0.097654
# principal_component_9     -0.265245
# principal_component_10     0.173155
# principal_component_11    -0.194850
# principal_component_12     0.073140
# principal_component_13     0.244606
# principal_component_14     0.221314
# principal_component_15    -0.376540
# principal_component_16     0.297656
# principal_component_17    -0.061235
# principal_component_18    -0.334608
# principal_component_19     0.674362
# principal_component_20     0.122631
# principal_component_21     0.007502
# principal_component_22    -0.310262
# principal_component_23    -0.035486
# dtype: float64
#
# Average absolute error for SS on test set: 1.1519417580343172
# Intercept                 72.105882
# principal_component_1      2.451653
# principal_component_2     -0.608466
# principal_component_3     -0.230307
# principal_component_4      0.270181
# principal_component_5      0.704468
# principal_component_6      0.501211
# principal_component_7     -0.090495
# principal_component_8      0.131812
# principal_component_9      0.034009
# principal_component_10    -0.390806
# principal_component_11     0.347031
# principal_component_12     0.118269
# principal_component_13     0.011123
# principal_component_14     0.329913
# principal_component_15    -0.669043
# principal_component_16    -0.476694
# principal_component_17     1.061846
# principal_component_18     0.494948
# principal_component_19    -0.355029
# principal_component_20    -0.030358
# principal_component_21     0.107248
# principal_component_22     0.055005
# principal_component_23     0.339383
# principal_component_24    -0.056787
# principal_component_25    -0.296483
# principal_component_26    -0.104898
# principal_component_27    -0.169428
# dtype: float64
#
# Average absolute error for TE on test set: 1.105322142254269
# Intercept                 61.610778
# principal_component_1     -3.499743
# principal_component_2     -0.355251
# principal_component_3     -1.279147
# principal_component_4      0.177770
# principal_component_5      0.511717
# principal_component_6     -0.111627
# principal_component_7     -1.593263
# principal_component_8      0.609159
# principal_component_9     -0.055246
# principal_component_10     0.282920
# principal_component_11     0.618274
# principal_component_12     0.164414
# principal_component_13     0.327958
# principal_component_14     0.057234
# principal_component_15     0.492353
# principal_component_16    -0.401165
# principal_component_17     0.761152
# principal_component_18     1.050307
# principal_component_19    -0.121315
# principal_component_20    -0.374508
# principal_component_21    -1.152923
# dtype: float64
#
# Average absolute error for WR on test set: 0.7002316604737902
# Intercept                 72.544747
# principal_component_1      2.011285
# principal_component_2     -0.941255
# principal_component_3     -0.296483
# principal_component_4      0.459580
# principal_component_5     -0.178240
# principal_component_6     -0.089548
# principal_component_7      0.316677
# principal_component_8      0.138070
# principal_component_9     -0.371861
# principal_component_10     0.584121
# principal_component_11     0.253250
# principal_component_12    -0.108437
# principal_component_13    -0.226754
# principal_component_14     0.088082
# principal_component_15    -0.066931
# principal_component_16     0.000456
# principal_component_17     0.104078
# principal_component_18    -0.074230
# principal_component_19    -0.268934
# principal_component_20    -0.086174
# principal_component_21    -0.605379
# principal_component_22    -0.047140
# principal_component_23     0.024357
# principal_component_24    -0.269905
# principal_component_25    -0.162844
# principal_component_26    -0.078204
# principal_component_27     0.080238
# principal_component_28    -0.231471
# principal_component_29     0.061054
# dtype: float64
